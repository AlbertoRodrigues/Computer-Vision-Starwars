# %%
import cv2
import numpy as np
import matplotlib.pyplot as pt
from PIL import Image
import imutils

# %% [markdown]
# # Tarefa 1

# %%
#Exemplo de imagem
end="Yoda\download36.jpg"
img=cv2.imread(end)

# %%
def visualiza_opencv(img):
    cv2.imshow("Imagem",img)
    cv2.waitKey()
    cv2.destroyAllWindows()

# %%
visualiza_opencv(img)

# %%
im = Image.open(end)

# %%
def visualiza_pil(im):     
    im.show()

# %%
visualiza_pil(im)

# %%
def visualiza_mat(im):   
    pt.imshow(im)

# %%
visualiza_mat(img)

# %% [markdown]
# # Tarefa 2

# %% [markdown]
# # Manual

# %%
def transforma_em_cinza(img):    
    return(np.floor(0.114*img[:,:,0]+0.587*img[:,:,1]+0.299*img[:,:,2]).astype("uint8"))

# %%
Image.fromarray(transforma_em_cinza(img))
# Out:
# <PIL.Image.Image image mode=L size=292x173 at 0x291B9E694F0>

# %% [markdown]
# # Usando opencv

# %%
cinza = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
Image.fromarray(cinza)
# Out:
# <PIL.Image.Image image mode=L size=292x173 at 0x291B9F38460>

# %% [markdown]
# ## Leia também sobre a diferença entre espaço RGB e BGR. Qual é usado pela biblioteca OpenCV?
# ### BGR!

# %% [markdown]
# # Tarefa 3

# %% [markdown]
# ## Funções implementadas usand numpy:

# %% [markdown]
# # Inverter a imagem (flip)

# %%
def inversao_imagem(img):    
    return(img[:,::-1,:])

# %% [markdown]
# # Imagem original

# %%
Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=RGB size=292x173 at 0x291BB08AE80>

# %%
Image.fromarray(inversao_imagem(img))
# Out:
# <PIL.Image.Image image mode=RGB size=292x173 at 0x291B9E3CC70>

# %% [markdown]
# # Zoom aleatorio

# %%
def zoom_aleatorio(img):   
    tamanho_janela=np.int(np.ceil(img.shape[0]/2))
    linha_zoom=np.random.randint(0, img.shape[0]-tamanho_janela)
    coluna_zoom=np.random.randint(0, img.shape[1]-tamanho_janela)
    img_zoom=img[linha_zoom:(linha_zoom+tamanho_janela),coluna_zoom:(coluna_zoom+tamanho_janela),:]
    return(cv2.resize(img_zoom,(img.shape[0], img.shape[1])))

# %%
Image.fromarray(zoom_aleatorio(img))
# Out:
# <PIL.Image.Image image mode=RGB size=173x292 at 0x291B9E3CF70>

# %% [markdown]
# # Funções usando open cv

# %% [markdown]
# ### Inversao

# %% [markdown]
# # Imagem original

# %%
Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=RGB size=292x173 at 0x291B9E3CF10>

# %%
Image.fromarray(cv2.flip(img,1))
# Out:
# <PIL.Image.Image image mode=RGB size=292x173 at 0x291BA041160>

# %% [markdown]
# # Rotação

# %%
rotated = imutils.rotate_bound(img, 92)
Image.fromarray(rotated)
# Out:
# <PIL.Image.Image image mode=RGB size=183x297 at 0x291B9E7C9D0>

# %% [markdown]
# # Zoom aleatorio

# %%
pts1 = np.float32([[56,65],[368,52],[28,387],[389,390]])
pts2 = np.float32([[0,0],[300,0],[0,300],[300,300]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(300,300))

# %%
Image.fromarray(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x291B9E257C0>

# %% [markdown]
# # Brilho e/ou contraste aleatorio

# %%
alpha=1
beta=100
new_image = np.zeros(img.shape, img.dtype)
for y in range(img.shape[0]):
    for x in range(img.shape[1]):
        for c in range(img.shape[2]):
            new_image[y,x,c] = np.clip(alpha*img[y,x,c] + beta, 0, 255)

# %%
Image.fromarray(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=292x173 at 0x291B9ED8940>

# %% [markdown]
# # Tarefa 4

# %% [markdown]
# ## Imagem original

# %%
cinza= transforma_em_cinza(img)

# %%
Image.fromarray(cinza)
# Out:
# <PIL.Image.Image image mode=L size=292x173 at 0x291B9E25580>

# %%
def filtro_media(img, tam):
    return(cv2.blur(img, (tam,tam) ))

# %%
Image.fromarray(filtro_media(cinza, 5))
# Out:
# <PIL.Image.Image image mode=L size=292x173 at 0x291B9E32640>

# %%
def filtro_gaussian_blur(img, tam):
    return(cv2.GaussianBlur(img, (tam,tam), 0 ))

# %%
Image.fromarray(filtro_gaussian_blur(cinza, 5))
# Out:
# <PIL.Image.Image image mode=L size=292x173 at 0x291BB0BB940>

# %%
def filtro_mediana(img, tam):
    return(cv2.medianBlur(img, tam))

# %%
Image.fromarray(filtro_mediana(cinza, 5))
# Out:
# <PIL.Image.Image image mode=L size=292x173 at 0x291BB0594C0>
